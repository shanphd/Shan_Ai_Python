# %% [markdown]
# ###  Data Flow through Function

# %%
from IPython.display import Image,display
display(Image("40.2.png",width=400))
display(Image("40.3.png",width=400))
display(Image("40.4.png",width=400))
display(Image("40.5.png",width=400))
display(Image("40.6.png",width=400))

# %%
# Python Function and Arguments 

# This function make text clean 

def clean_text(name):
    print(name.strip().lower())

# %%
clean_text("SHAN  ")
clean_text(" BOB  ")
# Out:
# shan
# bob
