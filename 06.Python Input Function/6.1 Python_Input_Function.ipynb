# %% [markdown]
# ## 6.1 Python Input Function

# %%
from IPython.display import Image,display
display(Image("6.2 What is input.png",width=300))
display(Image("6.3 input explain.png",width=300))
display(Image("6.4 Variable .png",width=300))
display(Image("6.5 Hardcode value.png",width=300))
display(Image("6.6 Dynamic.png",width=300))
display(Image("6.7 input value.png",width=300))
display(Image("6.8 Full function.png",width=300))

# %%
## Input Example 

# Dynamic Value
Name = input("Enter your name :  .") 
 
# Static Value
Role = 'Data Scientist' 
 
Company = 'DTCC' 

print(f"My name is {Name}, Role is {Role}, Company i am working {Company}.")
# Out:
# My name is G Shankar, Role is Data Scientist, Company i am working DTCC.
