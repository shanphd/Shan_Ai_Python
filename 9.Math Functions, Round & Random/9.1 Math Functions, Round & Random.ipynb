# %% [markdown]
# ## 9.Math Functions, Round & Random

# %%
from IPython.display import Image,display
display(Image("9.2 mathfunc.png",width=500))

# %% [markdown]
# ### 9.1 Math Function types

# %%
x = 9
y = 9.9 
z = 9 + 9j 
print(f"The type for x for {x} is {type(x)}")
print(f"The type for y for {y} is {type(y)}")
print(f"The type for z for {z} is {type(z)}")
# Out:
# The type for x for 9 is <class 'int'>
# The type for y for 9.9 is <class 'float'>
# The type for z for (9+9j) is <class 'complex'>

# %% [markdown]
# ### 9.2 Conversion

# %%
x = 9 

#convert int into float 
print(type(x))
print(f"converting into float {float(9)}") 

y = "99"
z= int(y)

#convert str into intand multiply by 2
print(type(y)) 
print(f"converting into int {int(y)} and multpity with 2 ans is  {z * 2}")

# convert into complex 

a = 9 

print(f"converting into complex {complex(y)} ")
# Out:
# <class 'int'>
# converting into float 9.0
# <class 'str'>
# converting into int 99 and multpity with 2 ans is  198
# converting into complex (99+0j)
