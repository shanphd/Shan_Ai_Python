# %% [markdown]
# ## 5. Python Variables

# %% [markdown]
# ## 5.1 How Varilable Works

# %%
from IPython.display import Image
Image("5.2 Variable.png", width=500)

# %%
from IPython.display import Image,display
display (Image("5.3 Variable How it works.png", width=500)) 
display (Image("5.4 how it works.png", width=500))

# %%
from IPython.display import Image,display
display(Image("5.5 varibales update.png",width=400))
display(Image("5.6 line.png",width=400))

# %%
## Python Variables Examples 


name = 'shan'
Role = 'Ai Data Scientist'
Age = 37 


## Combination of static and Dynamic 

print(f"My Name is {name},\nMy Role is {Role},\nMy Age is {Age}.")
# Out:
# My Name is shan,
# My Role is Ai Data Scientist,
# My Age is 37.
