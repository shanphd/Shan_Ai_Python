# %% [markdown]
# ### 16. Python If-Else One Line and Match-Case

# %%
from IPython.display import Image,display
display(Image("16.2 w.png",width=500))
display(Image("16.3.png",width=500))
display(Image("16.4.png",width=500))
display(Image("16.5.png",width=500))
display(Image("16.6.png",width=500))
display(Image("16.7.png",width=500))
display(Image("16.8.png",width=500))

# %%
# INline code example 
score = 75

grade = "A" if score >= 90 else "B" if score >= 80 else "F" 
print(grade)
# Out:
# F

# %% [markdown]
# ## Match Case statement

# %%
country = "IN"
match country:
    case "united states" | "usa":
        print("USA")
    case "India"| "IND":
        print("IN")
    case _:
        print("Unknown")
# Out:
# Unknown
