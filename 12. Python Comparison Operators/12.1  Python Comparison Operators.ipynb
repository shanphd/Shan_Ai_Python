# %% [markdown]
# ### 12.1 Python Comparison Operators

# %%
from IPython.display import Image,display
display(Image("12.2 def.png",width=500))
display(Image("12.3 ope.png",width=500))

# %%
## Comparision Example 

x = 7 
y = 9 

print (x < y)
print (x > y)
print ( x == y )
print ( x != y)
# Out:
# True
# False
# False
# True

# %%
x = 100
y = 200 

print ( x <= y)
print ( x !=y)
# Out:
# True
# True

# %% [markdown]
# ### Use case to check age is between 18 and 40

# %%
#chanined comparsion 

def voter_id(age):
    if 18 >= age <= 40:  # it is like between in sql
        return "you can vote"
    else:
        return "You cant vote"
        
print(voter_id(45))
# Out:
# You cant vote

# %%
from IPython.display import Image,display
display(Image("12.4 chain.png",width=500))
