# %% [markdown]
# ### 23. How to create List

# %%
from IPython.display import Image,display
display(Image("20.0.png",width=500))

# %%
from IPython.display import Image,display
display(Image("20.1 list.png",width=500))

# %%
## List character 

empty = []
print(type(empty))
# Out:
# <class 'list'>

# %%
letter = ['a','b','c']
print(letter)
print(type(letter))
# Out:
# ['a', 'b', 'c']
# <class 'list'>

# %%
# Mixed combination 

mixed = ['a','@',123,True]
print(mixed)
print(type(mixed))
# Out:
# ['a', '@', 123, True]
# <class 'list'>

# %%
# List Function 
name = 'python'

print(list(name))
# Out:
# ['p', 'y', 't', 'h', 'o', 'n']

# %%
from IPython.display import Image,display
display(Image("20.2 outer.png",width=500))
display(Image("20.3 sum.png",width=500))

# %%
## Nested Matrix 

mix_matrix = [["a","b","c"],
              [1,2,3],
              [True,False]] 

print(mix_matrix)

for row in mix_matrix:
    for item in row:
        print(item, end=" ")
    print()
# Out:
# [['a', 'b', 'c'], [1, 2, 3], [True, False]]
# a b c
# 1 2 3
# True False
