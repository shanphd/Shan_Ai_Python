# %% [markdown]
# ### Python Functions Made Simple

# %%
from IPython.display import Image,display
display(Image("39.2.png",width=400))
display(Image("39.3.png",width=400))
display(Image("39.4.png",width=400))
display(Image("39.5.png",width=400))
display(Image("39.6.png",width=400))
display(Image("39.7.png",width=400))
display(Image("39.8.png",width=400))
display(Image("39.9.png",width=400))

# %%
# Python Function

from IPython.display import Image,display
display(Image("39.10.png",width=400))
display(Image("39.11.png",width=400))

# %%
# Python Function just calling

name = 'shan'
print(len(name))
# Out:
# 4

# %%
# Python Function import calling 

import math
salary = 234.56 # want to round off 
print(math.ceil(salary))
# Out:
# 235

# %%
# Python user defined fuction 

def shan_sfk():
    for i in range (1,5):
        print(i)

shan_sfk()
# Out:
# 1
# 2
# 3
# 4

# %%
def shan_sfk_team():
    print('shan')
    print('Arjun')
    print('Tom')

# %%
print(f"Snowflake Team List")
print(f'#'*5)
shan_sfk_team()
print(f"#"*5)
# Out:
# Snowflake Team List
# #####
# shan
# Arjun
# Tom
# #####
