# %% [markdown]
# ## 7.1 Python Data Types

# %%
from IPython.display import Image,display
display(Image("7.2 Data types Values.png",width=300))
display(Image("7.3 Data types Boxes.png",width=300))

# %% [markdown]
# ## 7.2 Python Data Types Full List

# %%
from IPython.display import Image,display
display(Image("7.4 Python Full Data Types.png",width=700))
