# %% [markdown]
# ### 3.1 Python Comments

# %%
# 1.Single line Comment : Uses the # symbol — everything after it on that line is ignored by Python.

# This Program prints variable name

name = 'shan' 
print (name)
# Out:
# shan

# %%
# 2.Inline Comments : A # comment placed on the same line as code.

x = 4
y = x * 2  # Multiply x * 2 

print(y) # Generates Output
# Out:
# 8

# %%
# 3.Multi Line Comment : Python has no dedicated multi-line comment syntax. The convention is to use multiple # lines:

# This is block of comment
# So adding multiple lines

# %%
# 4. TODO Notes Comment : Common annotations used by developers to flag things for later:

# TODO: Need to refactor the Code 

name = 'shan'
age = 39
job = 'Data scientist in Snowflake'

print(f"My name is {name}, age is {age}, Working as {job}.") # FIXME: need to fix print statement
# Out:
# My name is shan, age is 39, Working as Data scientist in Snowflake.

# %%
# 5. Docstrings (Documentation Strings) : Triple-quoted strings (""" or ''') used to document modules, classes, and functions. Technically a string, not a comment, but widely used for documentation:

def greet(name):
    """
    This Function greet a Person 
    
    Args:
    name(str): The Person's Name
    
    Returns:
    str : A greeting message
    """
    return f"Hello welcome to Data science Ai World {name} :)"

# %%
print(greet("shan"))
# Out:
# Hello welcome to Data science Ai World shan :)
