# %% [markdown]
# ###14.1 Python Membership & Identity Operators

# %%
from IPython.display import Image,display
display(Image("14.2 flow.png",width=500))

# %% [markdown]
# ## in and notin example

# %%
name = ['shan','john','wenger']

#in example 

print('shan' in name)
print('arsenal' in name)

#not in 

print ('shan' not in name)
print('arsenal' not in name)
# Out:
# True
# False
# False
# True
