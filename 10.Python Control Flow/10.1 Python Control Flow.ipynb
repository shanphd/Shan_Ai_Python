# %% [markdown]
# ### 10.1 Python Control Flow

# %%
from IPython.display import Image,display
display(Image("10.2 control flow.png",width=500))
display(Image("10.3 str.png",width=500))
display(Image("10.3 sta.png",width=500))
display(Image("10.5loops.png",width=500))

# %% [markdown]
# ### 10.3 Control Flow very Important

# %%
from IPython.display import Image,display
display(Image("10.6 controlflow.png",width=700))
